# %%
from langchain_core.messages import HumanMessage
from models import ScrapeChatModel

# 1. Instantiate 
model = ScrapeChatModel(headless=False)

# %%
topics = ["India", "Vietnam", "Hawai", "DSA" , "Machine Learning", "Data Science", "Strawberry Ice Cream", "Soda", "Best pizza in the world", "What is Modi doing in Italy"]

responses = []

for topic in topics:
    responses.append(model.invoke(f"Give me 30 words explanation about {topic}"))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 6
#       2
#       3 responses = []
#       4
#       5 for topic in topics:
# ----> 6     responses.append(model.invoke(f"Give me 30 words explanation about {topic}"))
#
# File ~/Projects/chrome/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:474, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     460 @override
#     461 def invoke(
#     462     self,
#    (...)    467     **kwargs: Any,
#     468 ) -> AIMessage:
#     469     config = ensure_config(config)
#     470     return cast(
#     471         "AIMessage",
#     472         cast(
#     473             "ChatGeneration",
# --> 474             self.generate_prompt(
#     475                 [self._convert_input(input)],
#     476                 stop=stop,
# ...
